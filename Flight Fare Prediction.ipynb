# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
data=pd.read_excel(r"C:\Users\Ritika Shah\Downloads\ML Live Flight Fare Resourses16963295320.xlsx")

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
data.isnull().any()
# Out:
# Airline            False
# Date_of_Journey    False
# Source             False
# Destination        False
# Route               True
# Dep_Time           False
# Arrival_Time       False
# Duration           False
# Total_Stops         True
# Additional_Info    False
# Price              False
# dtype: bool

# %%
data[data["Total_Stops"].isnull()]
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  \
# 9039  Air India       6/05/2019  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price
# 9039  09:25 07 May  23h 40m         NaN         No info   7480

# %%
data[data["Route"].isnull()]
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  \
# 9039  Air India       6/05/2019  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price
# 9039  09:25 07 May  23h 40m         NaN         No info   7480

# %%
data["Additional_Info"].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
data.drop("Additional_Info", axis=1, inplace = True)

# %%
data.drop("Route", axis=1, inplace = True)

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination Dep_Time  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi    22:20
# 1        Air India       1/05/2019   Kolkata    Banglore    05:50
# 2      Jet Airways       9/06/2019     Delhi      Cochin    09:25
# 3           IndiGo      12/05/2019   Kolkata    Banglore    18:05
# 4           IndiGo      01/03/2019  Banglore   New Delhi    16:50
# ...            ...             ...       ...         ...      ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore    19:55
# 10679    Air India      27/04/2019   Kolkata    Banglore    20:45
# 10680  Jet Airways      27/04/2019  Banglore       Delhi    08:20
# 10681      Vistara      01/03/2019  Banglore   New Delhi    11:30
# 10682    Air India       9/05/2019     Delhi      Cochin    10:55
#
#        Arrival_Time Duration Total_Stops  Price
# 0      01:10 22 Mar   2h 50m    non-stop   3897
# 1             13:15   7h 25m     2 stops   7662
# ...

# %%
data.isnull().any()
# Out:
# Airline            False
# Date_of_Journey    False
# Source             False
# Destination        False
# Dep_Time           False
# Arrival_Time       False
# Duration           False
# Total_Stops        False
# Price              False
# dtype: bool

# %%
data.dropna(inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10682 entries, 0 to 10682
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10682 non-null  object
#  1   Date_of_Journey  10682 non-null  object
#  2   Source           10682 non-null  object
#  3   Destination      10682 non-null  object
#  4   Dep_Time         10682 non-null  object
#  5   Arrival_Time     10682 non-null  object
#  6   Duration         10682 non-null  object
#  7   Total_Stops      10682 non-null  object
#  8   Price            10682 non-null  int64
# dtypes: int64(1), object(8)
# memory usage: 834.5+ KB

# %%
data= pd.get_dummies(data, columns=["Airline"], dtype=int)

# %%
data
# Out:
#       Date_of_Journey    Source Destination Dep_Time  Arrival_Time Duration  \
# 0          24/03/2019  Banglore   New Delhi    22:20  01:10 22 Mar   2h 50m
# 1           1/05/2019   Kolkata    Banglore    05:50         13:15   7h 25m
# 2           9/06/2019     Delhi      Cochin    09:25  04:25 10 Jun      19h
# 3          12/05/2019   Kolkata    Banglore    18:05         23:30   5h 25m
# 4          01/03/2019  Banglore   New Delhi    16:50         21:35   4h 45m
# ...               ...       ...         ...      ...           ...      ...
# 10678       9/04/2019   Kolkata    Banglore    19:55         22:25   2h 30m
# 10679      27/04/2019   Kolkata    Banglore    20:45         23:20   2h 35m
# 10680      27/04/2019  Banglore       Delhi    08:20         11:20       3h
# 10681      01/03/2019  Banglore   New Delhi    11:30         14:10   2h 40m
# 10682       9/05/2019     Delhi      Cochin    10:55         19:15   8h 20m
#
# ...

# %%
data= pd.get_dummies(data, columns=["Source"], dtype=int)

# %%
data= pd.get_dummies(data, columns=["Destination"], dtype=int)

# %%
data
# Out:
#       Date_of_Journey Dep_Time  Arrival_Time Duration Total_Stops  Price  \
# 0          24/03/2019    22:20  01:10 22 Mar   2h 50m    non-stop   3897
# 1           1/05/2019    05:50         13:15   7h 25m     2 stops   7662
# 2           9/06/2019    09:25  04:25 10 Jun      19h     2 stops  13882
# 3          12/05/2019    18:05         23:30   5h 25m      1 stop   6218
# 4          01/03/2019    16:50         21:35   4h 45m      1 stop  13302
# ...               ...      ...           ...      ...         ...    ...
# 10678       9/04/2019    19:55         22:25   2h 30m    non-stop   4107
# 10679      27/04/2019    20:45         23:20   2h 35m    non-stop   4145
# 10680      27/04/2019    08:20         11:20       3h    non-stop   7229
# 10681      01/03/2019    11:30         14:10   2h 40m    non-stop  12648
# 10682       9/05/2019    10:55         19:15   8h 20m     2 stops  11753
#
#        Airline_Air Asia  Airline_Air India  Airline_GoAir  Airline_IndiGo  \
# ...

# %%
pd.to_datetime(data["Date_of_Journey"]) # Dateformat= year-month-date
# Out:
# C:\Users\Ritika Shah\AppData\Local\Temp\ipykernel_18232\1948586113.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   pd.to_datetime(data["Date_of_Journey"])
# 0       2019-03-24
# 1       2019-05-01
# 2       2019-06-09
# 3       2019-05-12
# 4       2019-03-01
#            ...
# 10678   2019-04-09
# 10679   2019-04-27
# 10680   2019-04-27
# 10681   2019-03-01
# 10682   2019-05-09
# Name: Date_of_Journey, Length: 10682, dtype: datetime64[ns]

# %%
data["Day"]=pd.to_datetime(data["Date_of_Journey"]).dt.day
# Out:
# C:\Users\Ritika Shah\AppData\Local\Temp\ipykernel_18232\2441515507.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data["Day"]=pd.to_datetime(data["Date_of_Journey"]).dt.day

# %%
data["Month"]=pd.to_datetime(data["Date_of_Journey"]).dt.month
# Out:
# C:\Users\Ritika Shah\AppData\Local\Temp\ipykernel_18232\3019864977.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data["Month"]=pd.to_datetime(data["Date_of_Journey"]).dt.month

# %%
data["Year"]=pd.to_datetime(data["Date_of_Journey"]).dt.year
# Out:
# C:\Users\Ritika Shah\AppData\Local\Temp\ipykernel_18232\1557994649.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data["Year"]=pd.to_datetime(data["Date_of_Journey"]).dt.year

# %%
data
# Out:
#       Date_of_Journey Dep_Time  Arrival_Time Duration Total_Stops  Price  \
# 0          24/03/2019    22:20  01:10 22 Mar   2h 50m    non-stop   3897
# 1           1/05/2019    05:50         13:15   7h 25m     2 stops   7662
# 2           9/06/2019    09:25  04:25 10 Jun      19h     2 stops  13882
# 3          12/05/2019    18:05         23:30   5h 25m      1 stop   6218
# 4          01/03/2019    16:50         21:35   4h 45m      1 stop  13302
# ...               ...      ...           ...      ...         ...    ...
# 10678       9/04/2019    19:55         22:25   2h 30m    non-stop   4107
# 10679      27/04/2019    20:45         23:20   2h 35m    non-stop   4145
# 10680      27/04/2019    08:20         11:20       3h    non-stop   7229
# 10681      01/03/2019    11:30         14:10   2h 40m    non-stop  12648
# 10682       9/05/2019    10:55         19:15   8h 20m     2 stops  11753
#
#        Airline_Air Asia  Airline_Air India  Airline_GoAir  Airline_IndiGo  \
# ...

# %%
data.drop("Date_of_Journey", axis=1, inplace=True)

# %%
data
# Out:
#       Dep_Time  Arrival_Time Duration Total_Stops  Price  Airline_Air Asia  \
# 0        22:20  01:10 22 Mar   2h 50m    non-stop   3897                 0
# 1        05:50         13:15   7h 25m     2 stops   7662                 0
# 2        09:25  04:25 10 Jun      19h     2 stops  13882                 0
# 3        18:05         23:30   5h 25m      1 stop   6218                 0
# 4        16:50         21:35   4h 45m      1 stop  13302                 0
# ...        ...           ...      ...         ...    ...               ...
# 10678    19:55         22:25   2h 30m    non-stop   4107                 1
# 10679    20:45         23:20   2h 35m    non-stop   4145                 0
# 10680    08:20         11:20       3h    non-stop   7229                 0
# 10681    11:30         14:10   2h 40m    non-stop  12648                 0
# 10682    10:55         19:15   8h 20m     2 stops  11753                 0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10682 entries, 0 to 10682
# Data columns (total 31 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Dep_Time                                   10682 non-null  object
#  1   Arrival_Time                               10682 non-null  object
#  2   Duration                                   10682 non-null  object
#  3   Total_Stops                                10682 non-null  object
#  4   Price                                      10682 non-null  int64
#  5   Airline_Air Asia                           10682 non-null  int64
#  6   Airline_Air India                          10682 non-null  int64
#  7   Airline_GoAir                              10682 non-null  int64
#  8   Airline_IndiGo                             10682 non-null  int64
#  9   Airline_Jet Airways                        10682 non-null  int64
# ...

# %%
data["Dept_Hour"]=pd.to_datetime(data["Dep_Time"]).dt.hour
# Out:
# C:\Users\Ritika Shah\AppData\Local\Temp\ipykernel_18232\3230103755.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data["Dept_Hour"]=pd.to_datetime(data["Dep_Time"]).dt.hour

# %%
data["Dept_Minutes"]=pd.to_datetime(data["Dep_Time"]).dt.minute
# Out:
# C:\Users\Ritika Shah\AppData\Local\Temp\ipykernel_18232\2999108211.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data["Dept_Minutes"]=pd.to_datetime(data["Dep_Time"]).dt.minute

# %%
data["Arrival_Hour"]=pd.to_datetime(data["Arrival_Time"]).dt.hour
# Out:
# C:\Users\Ritika Shah\AppData\Local\Temp\ipykernel_18232\4046598154.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data["Arrival_Hour"]=pd.to_datetime(data["Arrival_Time"]).dt.hour

# %%
data["Arrival_Minutes"]=pd.to_datetime(data["Arrival_Time"]).dt.minute
# Out:
# C:\Users\Ritika Shah\AppData\Local\Temp\ipykernel_18232\2888277772.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data["Arrival_Minutes"]=pd.to_datetime(data["Arrival_Time"]).dt.minute

# %%
data
# Out:
#       Dep_Time  Arrival_Time Duration Total_Stops  Price  Airline_Air Asia  \
# 0        22:20  01:10 22 Mar   2h 50m    non-stop   3897                 0
# 1        05:50         13:15   7h 25m     2 stops   7662                 0
# 2        09:25  04:25 10 Jun      19h     2 stops  13882                 0
# 3        18:05         23:30   5h 25m      1 stop   6218                 0
# 4        16:50         21:35   4h 45m      1 stop  13302                 0
# ...        ...           ...      ...         ...    ...               ...
# 10678    19:55         22:25   2h 30m    non-stop   4107                 1
# 10679    20:45         23:20   2h 35m    non-stop   4145                 0
# 10680    08:20         11:20       3h    non-stop   7229                 0
# 10681    11:30         14:10   2h 40m    non-stop  12648                 0
# 10682    10:55         19:15   8h 20m     2 stops  11753                 0
#
# ...

# %%
data.drop(["Dep_Time","Arrival_Time"], axis=1, inplace=True)

# %%
data
# Out:
#       Duration Total_Stops  Price  Airline_Air Asia  Airline_Air India  \
# 0       2h 50m    non-stop   3897                 0                  0
# 1       7h 25m     2 stops   7662                 0                  1
# 2          19h     2 stops  13882                 0                  0
# 3       5h 25m      1 stop   6218                 0                  0
# 4       4h 45m      1 stop  13302                 0                  0
# ...        ...         ...    ...               ...                ...
# 10678   2h 30m    non-stop   4107                 1                  0
# 10679   2h 35m    non-stop   4145                 0                  1
# 10680       3h    non-stop   7229                 0                  0
# 10681   2h 40m    non-stop  12648                 0                  0
# 10682   8h 20m     2 stops  11753                 0                  1
#
#        Airline_GoAir  Airline_IndiGo  Airline_Jet Airways  \
# ...

# %%
data["Duration"]=data["Duration"].str.replace("h", "")

# %%
data["Duration"]= data["Duration"].str.replace("m", "")

# %%
data[["Duration_Hours", "Duration_Minutes"]]=data["Duration"].str.split(expand=True)  
# expand=True, pandas expands the list into multiple columns
#By default, .split() would return a list inside a column like     ["2", "50"]

# %%
data
# Out:
#       Duration Total_Stops  Price  Airline_Air Asia  Airline_Air India  \
# 0         2 50    non-stop   3897                 0                  0
# 1         7 25     2 stops   7662                 0                  1
# 2           19     2 stops  13882                 0                  0
# 3         5 25      1 stop   6218                 0                  0
# 4         4 45      1 stop  13302                 0                  0
# ...        ...         ...    ...               ...                ...
# 10678     2 30    non-stop   4107                 1                  0
# 10679     2 35    non-stop   4145                 0                  1
# 10680        3    non-stop   7229                 0                  0
# 10681     2 40    non-stop  12648                 0                  0
# 10682     8 20     2 stops  11753                 0                  1
#
#        Airline_GoAir  Airline_IndiGo  Airline_Jet Airways  \
# ...

# %%
data["Duration_Minutes"].unique()
# Out:
# array(['50', '25', None, '45', '30', '5', '15', '35', '10', '20', '55',
#        '40'], dtype=object)

# %%
data["Duration_Minutes"]= data["Duration_Minutes"].fillna(0).astype(int)

# %%
data
# Out:
#       Total_Stops  Price  Airline_Air Asia  Airline_Air India  Airline_GoAir  \
# 0        non-stop   3897                 0                  0              0
# 1         2 stops   7662                 0                  1              0
# 2         2 stops  13882                 0                  0              0
# 3          1 stop   6218                 0                  0              0
# 4          1 stop  13302                 0                  0              0
# ...           ...    ...               ...                ...            ...
# 10678    non-stop   4107                 1                  0              0
# 10679    non-stop   4145                 0                  1              0
# 10680    non-stop   7229                 0                  0              0
# 10681    non-stop  12648                 0                  0              0
# 10682     2 stops  11753                 0                  1              0
#
# ...

# %%
data.drop("Duration", axis=1, inplace=True)

# %%
data= pd.get_dummies(data, columns=["Total_Stops"], dtype=int)

# %%
data
# Out:
#        Price  Airline_Air Asia  Airline_Air India  Airline_GoAir  \
# 0       3897                 0                  0              0
# 1       7662                 0                  1              0
# 2      13882                 0                  0              0
# 3       6218                 0                  0              0
# 4      13302                 0                  0              0
# ...      ...               ...                ...            ...
# 10678   4107                 1                  0              0
# 10679   4145                 0                  1              0
# 10680   7229                 0                  0              0
# 10681  12648                 0                  0              0
# 10682  11753                 0                  1              0
#
#        Airline_IndiGo  Airline_Jet Airways  Airline_Jet Airways Business  \
# 0                   1                    0                             0
# ...

# %%
data.shape
# Out:
# (10682, 38)

# %%
# Create Target and Feature set.

# %%
x=data.drop("Price", axis=1)

# %%
y=data["Price"]

# %%
plt.figure(figsize = (30,30))
sns.heatmap(data.corr(), annot = True, cmap = "RdYlGn")

plt.show()

# %%
data.describe()
# Out:
#               Price  Airline_Air Asia  Airline_Air India  Airline_GoAir  \
# count  10682.000000      10682.000000       10682.000000   10682.000000
# mean    9087.214567          0.029863           0.163921       0.018161
# std     4611.548810          0.170218           0.370221       0.133541
# min     1759.000000          0.000000           0.000000       0.000000
# 25%     5277.000000          0.000000           0.000000       0.000000
# 50%     8372.000000          0.000000           0.000000       0.000000
# 75%    12373.000000          0.000000           0.000000       0.000000
# max    79512.000000          1.000000           1.000000       1.000000
#
#        Airline_IndiGo  Airline_Jet Airways  Airline_Jet Airways Business  \
# count    10682.000000         10682.000000                  10682.000000
# mean         0.192192             0.360326                      0.000562
# std          0.394042             0.480117                      0.023695
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test, y_train, y_test=train_test_split(x,y, train_size=0.8, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model=RandomForestRegressor(random_state=0)

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
model.score(x_train,y_train)*100
# Out:
# 95.32930221959148

# %%
model.score(x_test,y_test)*100
# Out:
# 79.61518714395363

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 1180.338959981694

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 4395384.829595689

# %%
r2_score(y_test, y_pred)
# Out:
# 0.7961518714395364

# %%
sns.distplot(y_test-y_pred)
plt.show()
# Out:
# C:\Users\Ritika Shah\AppData\Local\Temp\ipykernel_18232\3453123835.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-y_pred)

# %%
plt.scatter(y_test, y_pred, alpha = 0.5)
plt.xlabel("y_test")
plt.ylabel("y_pred")
plt.show()
